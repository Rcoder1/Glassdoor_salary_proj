# %%
import pandas as pd
data_frame = pd.read_csv("Glassdoor_jobs.csv")

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5578 entries, 0 to 5577
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5578 non-null   object
#  1   Salary Estimate    5578 non-null   object
#  2   Job Description    5578 non-null   object
#  3   Rating             5578 non-null   float64
#  4   Company Name       5578 non-null   object
#  5   Location           5578 non-null   object
#  6   Size               5578 non-null   object
#  7   Founded            5578 non-null   int64
#  8   Type of ownership  5578 non-null   object
#  9   Industry           5578 non-null   object
#  10  Sector             5578 non-null   object
#  11  Revenue            5578 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 523.1+ KB

# %%
data_frame.head(50)
# Out:
#                                             Job Title  \
# 0             Geospatial Researcher/Data Scientist IV
# 1                               Senior Data Scientist
# 2   Software Integrator / Data Scientist - Expert ...
# 3                                 Lead Data Scientist
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                           Defense Data Scientist II
# 7                                 Senior Data Analyst
# 8                                      Data Scientist
# 9                     Defense Senior Data Scientist I
# 10                                     Data Scientist
# 11                                     Data Scientist
# 12                 2023771 Data Scientist $215,000.00
# 13                              DATA SCIENTIST - USMS
# 14                                Junior Data Labeler
# 15                                     Data Scientist
# 16                     Tech Excellence Data Scientist
# 17                                     Data Scientist
# 18                              Senior Data Scientist
# 19                                     Data Scientist
# 20               Jr. Data Scientist (Remote Eligible)
# 21                                   Data Scientist I
# 22                                     Data Scientist
# 23                              Senior Data Scientist
# 24               Data Scientist - Electricity Markets
# 25                Data Scientist - Clearance Required
# 26                      Data Scientist with Polygraph
# 27                                     Data Scientist
# 28             Senior Data Scientist (Remote/On Site)
# 29                                     Data Scientist
# 30                         Defense Data Scientist III
# 31                         Defense Data Scientist III
# 32  Pharmaceutical/Biotech Market Research Data Sc...
# 33                             Data Scientist, Junior
# 34                                     Data Scientist
# 35   Jr. Machine Learning Data Scientist - Python / R
# 36                                     Data Scientist
# 37              Tech Excellence Data Engineer, Junior
# 38                                     Data Scientist
# 39                             Data Scientist/Analyst
# 40                        Data Scientist (ALL LEVELS)
# 41                                     Data Scientist
# 42                                     Data Scientist
# 43                              Junior Data Scientist
# 44                    Data Scientist / Data Analytics
# 45                                     Data Scientist
# 46                            Aviation Data Scientist
# 47                                     Data Scientist
# 48      Data Scientist (Hybrid) (Intelligence Center)
# 49                                     Data Scientist
#
#                                 Salary Estimate  \
# 0                 $76K - $120K (Glassdoor est.)
# 1                $101K - $138K (Glassdoor est.)
# 2                 $74K - $109K (Glassdoor est.)
# 3                $116K - $161K (Glassdoor est.)
# 4                 $76K - $108K (Glassdoor est.)
# 5         Employer Provided Salary:$65K - $205K
# 6                 $87K - $126K (Glassdoor est.)
# 7        Employer Provided Salary:$100K - $125K
# 8        Employer Provided Salary:$125K - $185K
# 9                 $96K - $137K (Glassdoor est.)
# 10       Employer Provided Salary:$160K - $200K
# 11       Employer Provided Salary:$110K - $115K
# 12               Employer Provided Salary:$215K
# 13        Employer Provided Salary:$50K - $300K
# 14                 $46K - $73K (Glassdoor est.)
# 15       Employer Provided Salary:$120K - $130K
# 16                $83K - $125K (Glassdoor est.)
# 17        Employer Provided Salary:$62K - $117K
# 18        Employer Provided Salary:$96K - $237K
# 19                $91K - $131K (Glassdoor est.)
# 20                 $48K - $74K (Glassdoor est.)
# 21                $89K - $127K (Glassdoor est.)
# 22       Employer Provided Salary:$100K - $130K
# 23  Employer Provided Salary:$70 - $75 Per Hour
# 24       Employer Provided Salary:$100K - $140K
# 25                $86K - $129K (Glassdoor est.)
# 26                $88K - $138K (Glassdoor est.)
# 27                $90K - $132K (Glassdoor est.)
# 28       Employer Provided Salary:$170K - $198K
# 29                $97K - $139K (Glassdoor est.)
# 30                $95K - $137K (Glassdoor est.)
# 31                $95K - $137K (Glassdoor est.)
# 32                $95K - $137K (Glassdoor est.)
# 33                $95K - $137K (Glassdoor est.)
# 34                $95K - $137K (Glassdoor est.)
# 35                $95K - $137K (Glassdoor est.)
# 36                $95K - $137K (Glassdoor est.)
# 37                $95K - $137K (Glassdoor est.)
# 38                $95K - $137K (Glassdoor est.)
# 39                $95K - $137K (Glassdoor est.)
# 40                $95K - $137K (Glassdoor est.)
# 41                $95K - $137K (Glassdoor est.)
# 42                $95K - $137K (Glassdoor est.)
# 43                $95K - $137K (Glassdoor est.)
# 44                $95K - $137K (Glassdoor est.)
# 45                $95K - $137K (Glassdoor est.)
# 46                $95K - $137K (Glassdoor est.)
# 47                $95K - $137K (Glassdoor est.)
# 48                $95K - $137K (Glassdoor est.)
# 49                $95K - $137K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 0   Battelle delivers when others can’t. We conduc...     3.6
# 1   JDSAT, Inc. is a solutions company - utilizing...     4.3
# 2   *** Must have TS/SCI ***\nJOB DESCRIPTION:\nIn...     4.6
# 3   Tensure is a fully-remote technology consultin...     3.8
# 4   JDSAT, Inc. is a solutions company - utilizing...     4.3
# 5   Data Scientist\nCome join the winning team on ...     4.3
# 6   Overview\n\nGuidehouse is a leading global pro...     3.7
# 7   This position requires 3 days per week onsite ...     3.8
# 8   Introduction:\nEpochGeo is looking for a Mid o...    -1.0
# 9   Overview\n\nGuidehouse is a leading global pro...     3.7
# 10  Data Scientist\nReston, Herndon, McLean, VA\nT...     5.0
# 11  Overview\nStaffing Pros, a division of VETS In...    -1.0
# 12  Position Requires a Top Secret (TS/SCI) Cleara...     5.0
# 13  The Data Scientist conducts quantitative analy...     3.6
# 14  Junior Data Labeler\n\nIn this age of disrupti...     4.0
# 15  The Program Development, Coordination, and Sup...     4.6
# 16  The Challenge:\nAre you excited at the prospec...     4.2
# 17  Duties\nAs a Data Scientist within the Geology...     4.0
# 18  Job Description:\nExperienced in data science ...    -1.0
# 19  Company Description\n\nVisa is a world leader ...     4.0
# 20  Location\nHQ\n3500 S Clark Street\nArlington, ...     3.2
# 21  YOUR LIFE'S MISSION: POSSIBLE\nYou have goals,...     4.1
# 22  The Program Development, Coordination, and Sup...    -1.0
# 23  Experienced in data science / machine learning...    -1.0
# 24  Data Scientist - Electricity Markets\nData Sci...    -1.0
# 25  Overview:\nLMI is a consultancy dedicated to p...     4.1
# 26  In this age of disruption, organizations need ...     4.0
# 27  About Us\nWe are a group of Technical Practiti...     5.0
# 28  Data Scientist\nOverview\nAs an employee, you ...    -1.0
# 29  To get the best candidate experience, please c...     4.4
# 30  Overview\n\nGuidehouse is a leading global pro...     3.7
# 31  Overview\n\nGuidehouse is a leading global pro...     3.7
# 32  Overview\n\nGuidehouse is a leading global pro...     3.7
# 33  Quadrint is a fast-growing, Information Techno...     4.4
# 34  At Boeing, we innovate and collaborate to make...     3.8
# 35  In this age of disruption, organizations need ...     4.0
# 36  Duties\nThis position is located in the Financ...     3.5
# 37  The Opportunity:\nEver-expanding technology li...     4.2
# 38  Overview: Staffing Pros, a division of VETS In...     3.9
# 39  Qualified candidate will become part of Perato...     3.6
# 40  Responsibilities:\nNoblis is seeking to hire D...     4.3
# 41  Pluribus Digital is looking for a talented Dat...     4.9
# 42  Harmonia Holdings Group, LLC, an award-winning...     4.1
# 43  Dark Wolf Solutions is looking for a Data Scie...     4.9
# 44  Overview:\nSkyePoint Decisions is a leading Cy...     3.5
# 45  Data Scientist\nFalls Church VA (Merrifield) /...     4.1
# 46  ATAC has an opening for an Aviation Data Scien...     3.9
# 47  Job Summary:\nLooking for a broadly talented D...     4.5
# 48  Why choose between doing meaningful work and h...     3.7
# 49  Duties\nMaking a Difference: HUD's Mission\nHU...    -1.0
#
#                                          Company Name  \
# 0                                            Battelle
# 1                                               JDSAT
# 2                                Que Technology Group
# 3                                  Tensure Consulting
# 4                                               JDSAT
# 5                                       GS Consulting
# 6                                          Guidehouse
# 7                            Bloomberg Industry Group
# 8                                            EpochGeo
# 9                                          Guidehouse
# 10                               The Josef Group Inc.
# 11             Staffing Pros, a division of VETS-inc.
# 12                                             B4CORP
# 13                                       Venesco, LLC
# 14                                           Deloitte
# 15                         Delaware Nation Industries
# 16                                Booz Allen Hamilton
# 17                               US Geological Survey
# 18                                   BRO. Consultants
# 19                                               Visa
# 20                                            Lidl US
# 21                          Navy Federal Credit Union
# 22                                                DNI
# 23                            Enormous Enterprise LLC
# 24                                  Potomac Economics
# 25                     Logistics Management Institute
# 26                                           Deloitte
# 27                                         whiteSpace
# 28                                          SourceFly
# 29                                         Salesforce
# 30                                         Guidehouse
# 31                                         Guidehouse
# 32                                         Guidehouse
# 33                                     Quadrint, Inc.
# 34                                             BOEING
# 35                                           Deloitte
# 36                             US Library of Congress
# 37                                Booz Allen Hamilton
# 38           Veterans Enterprise Technology Solutions
# 39                                            Peraton
# 40                                             Noblis
# 41                                   Pluribus Digital
# 42                       Harmonia Holdings Group, LLC
# 43                                Dark Wolf Solutions
# 44                                SkyePoint Decisions
# 45                                        Marathon TS
# 46                                               ATAC
# 47                           DT Professional Services
# 48                              The MITRE Corporation
# 49  US Office of Departmental Equal Employment Opp...
#
#                    Location                     Size  Founded  \
# 0          Fort Belvoir, VA   1001 to 5000 Employees     1929
# 1                McLean, VA        1 to 50 Employees       -1
# 2                McLean, VA        1 to 50 Employees       -1
# 3            Washington, DC        1 to 50 Employees       -1
# 4                McLean, VA        1 to 50 Employees       -1
# 5   Fort George G Meade, MD        1 to 50 Employees       -1
# 6                McLean, VA   1001 to 5000 Employees     2018
# 7            Washington, DC   1001 to 5000 Employees     1929
# 8            Washington, DC                       -1       -1
# 9                McLean, VA   1001 to 5000 Employees     2018
# 10              Herndon, VA        1 to 50 Employees       -1
# 11            Arlington, VA                       -1       -1
# 12               McLean, VA      51 to 200 Employees       -1
# 13            Arlington, VA     201 to 500 Employees     2004
# 14              Rosslyn, VA         10000+ Employees     1850
# 15            Arlington, VA                  Unknown       -1
# 16           Alexandria, VA         10000+ Employees     1914
# 17               Reston, VA  5001 to 10000 Employees     1879
# 18               McLean, VA                  Unknown       -1
# 19            Arlington, VA         10000+ Employees     1958
# 20            Arlington, VA  5001 to 10000 Employees     1973
# 21               Vienna, VA         10000+ Employees     1933
# 22            Arlington, VA                       -1       -1
# 23               McLean, VA      51 to 200 Employees     2016
# 24              Fairfax, VA                       -1       -1
# 25        Tysons Corner, VA   1001 to 5000 Employees     1961
# 26              Rosslyn, VA         10000+ Employees     1850
# 27           Washington, DC        1 to 50 Employees       -1
# 28         Fort Belvoir, VA                       -1       -1
# 29           Washington, DC         10000+ Employees     1999
# 30               McLean, VA   1001 to 5000 Employees     2018
# 31               McLean, VA   1001 to 5000 Employees     2018
# 32        Tysons Corner, VA   1001 to 5000 Employees     2018
# 33               McLean, VA      51 to 200 Employees     2000
# 34           Fort Meade, MD         10000+ Employees     1916
# 35              Rosslyn, VA         10000+ Employees     1850
# 36           Washington, DC   1001 to 5000 Employees     1800
# 37            Chantilly, VA         10000+ Employees     1914
# 38            Arlington, VA      51 to 200 Employees     2005
# 39            Arlington, VA         10000+ Employees     2017
# 40               Reston, VA   1001 to 5000 Employees     1996
# 41            Arlington, VA      51 to 200 Employees     1995
# 42               McLean, VA     201 to 500 Employees     2006
# 43               McLean, VA      51 to 200 Employees     2019
# 44              Rosslyn, VA        1 to 50 Employees     2009
# 45          Springfield, VA     201 to 500 Employees     2009
# 46            Arlington, VA      51 to 200 Employees       -1
# 47           Merrifield, VA        1 to 50 Employees     2013
# 48               McLean, VA  5001 to 10000 Employees     1958
# 49           Washington, DC                       -1       -1
#
#          Type of ownership                                 Industry  \
# 0   Nonprofit Organization                   Research & Development
# 1        Company - Private                                       -1
# 2        Company - Private                                       -1
# 3        Company - Private                                       -1
# 4        Company - Private                                       -1
# 5        Company - Private                                       -1
# 6        Company - Private                      Business Consulting
# 7        Company - Private                               Publishing
# 8                       -1                                       -1
# 9        Company - Private                      Business Consulting
# 10       Company - Private                                       -1
# 11                      -1                                       -1
# 12       Company - Private  Information Technology Support Services
# 13        Company - Public  Information Technology Support Services
# 14       Company - Private                         Accounting & Tax
# 15                Contract                        National Agencies
# 16        Company - Public                      Business Consulting
# 17              Government                        National Agencies
# 18        Company - Public                                       -1
# 19        Company - Public  Information Technology Support Services
# 20       Company - Private                           Grocery Stores
# 21           Self-employed                        Banking & Lending
# 22                      -1                                       -1
# 23       Company - Private  Information Technology Support Services
# 24                      -1                                       -1
# 25       Company - Private                      Business Consulting
# 26       Company - Private                         Accounting & Tax
# 27           Self-employed                                       -1
# 28                      -1                                       -1
# 29        Company - Public  Enterprise Software & Network Solutions
# 30       Company - Private                      Business Consulting
# 31       Company - Private                      Business Consulting
# 32       Company - Private                      Business Consulting
# 33       Company - Private  Information Technology Support Services
# 34        Company - Public                      Aerospace & Defense
# 35       Company - Private                         Accounting & Tax
# 36              Government                  Culture & Entertainment
# 37        Company - Public                      Business Consulting
# 38       Company - Private                        National Agencies
# 39       Company - Private  Information Technology Support Services
# 40  Nonprofit Organization                      Business Consulting
# 41       Company - Private  Information Technology Support Services
# 42       Company - Private            Computer Hardware Development
# 43       Company - Private                                       -1
# 44       Company - Private  Information Technology Support Services
# 45       Company - Private                            HR Consulting
# 46       Company - Private            Education & Training Services
# 47        Company - Public                                       -1
# 48  Nonprofit Organization                        National Agencies
# 49                      -1                                       -1
#
#                                 Sector                           Revenue
# 0              Management & Consulting           $5 to $10 billion (USD)
# 1                                   -1          Unknown / Non-Applicable
# 2                                   -1        Less than $1 million (USD)
# 3                                   -1          Unknown / Non-Applicable
# 4                                   -1          Unknown / Non-Applicable
# 5                                   -1          Unknown / Non-Applicable
# 6              Management & Consulting          Unknown / Non-Applicable
# 7                Media & Communication        $100 to $500 million (USD)
# 8                                   -1                                -1
# 9              Management & Consulting          Unknown / Non-Applicable
# 10                                  -1          Unknown / Non-Applicable
# 11                                  -1                                -1
# 12              Information Technology          Unknown / Non-Applicable
# 13              Information Technology          Unknown / Non-Applicable
# 14                  Financial Services                $10+ billion (USD)
# 15  Government & Public Administration          Unknown / Non-Applicable
# 16             Management & Consulting           $5 to $10 billion (USD)
# 17  Government & Public Administration          Unknown / Non-Applicable
# 18                                  -1          Unknown / Non-Applicable
# 19              Information Technology                $10+ billion (USD)
# 20                  Retail & Wholesale          Unknown / Non-Applicable
# 21                  Financial Services          Unknown / Non-Applicable
# 22                                  -1                                -1
# 23              Information Technology          Unknown / Non-Applicable
# 24                                  -1                                -1
# 25             Management & Consulting        $100 to $500 million (USD)
# 26                  Financial Services                $10+ billion (USD)
# 27                                  -1          Unknown / Non-Applicable
# 28                                  -1                                -1
# 29              Information Technology                $10+ billion (USD)
# 30             Management & Consulting          Unknown / Non-Applicable
# 31             Management & Consulting          Unknown / Non-Applicable
# 32             Management & Consulting          Unknown / Non-Applicable
# 33              Information Technology          Unknown / Non-Applicable
# 34                 Aerospace & Defense                $10+ billion (USD)
# 35                  Financial Services                $10+ billion (USD)
# 36    Arts, Entertainment & Recreation  $500 million to $1 billion (USD)
# 37             Management & Consulting           $5 to $10 billion (USD)
# 38  Government & Public Administration         $25 to $100 million (USD)
# 39              Information Technology           $5 to $10 billion (USD)
# 40             Management & Consulting        $100 to $500 million (USD)
# 41              Information Technology          Unknown / Non-Applicable
# 42              Information Technology         $25 to $100 million (USD)
# 43                                  -1          Unknown / Non-Applicable
# 44              Information Technology           $5 to $25 million (USD)
# 45          Human Resources & Staffing         $25 to $100 million (USD)
# 46                           Education           $5 to $25 million (USD)
# 47                                  -1        Less than $1 million (USD)
# 48  Government & Public Administration            $1 to $5 billion (USD)
# 49                                  -1                                -1

# %%
#drop duplicate job postings 
data_frame.drop_duplicates(inplace = True)
data_frame.shape
# Out:
# (3440, 12)

# %% [markdown]
# Number of rows got reduced from 5578 to 3440 after removing the duplictaes

# %%
# to check if there are any null values in Salary column
data_frame['Salary Estimate'].isna().sum()
# Out:
# 0

# %%
# checking for types of values Salary Estimate column holds
data_frame['Salary Estimate'].value_counts()
# Out:
# $135K - $175K (Employer est.)             155
# -1                                        134
# $65K - $205K (Employer est.)              110
# $180K - $260K (Employer est.)              86
# $210K - $304K (Employer est.)              76
#                                          ...
# Employer Provided Salary:$140K - $145K      1
# $77K - $108K (Glassdoor est.)               1
# $67K - $97K (Glassdoor est.)                1
# $78K - $113K (Glassdoor est.)               1
# $112K - $157K (Glassdoor est.)              1
# Name: Salary Estimate, Length: 810, dtype: int64

# %%
# deleting 134 rows with no salary information (-1 values). This is around 0.04% of the total number of rows
data_frame = data_frame[data_frame['Salary Estimate'] != '-1']
data_frame.shape
# Out:
# (3306, 12)

# %%
data_frame['Salary Estimate'].value_counts()
# Out:
# $135K - $175K (Employer est.)             155
# $65K - $205K (Employer est.)              110
# $180K - $260K (Employer est.)              86
# $210K - $304K (Employer est.)              76
# $120K - $140K (Employer est.)              67
#                                          ...
# Employer Provided Salary:$140K - $145K      1
# $77K - $108K (Glassdoor est.)               1
# $67K - $97K (Glassdoor est.)                1
# $78K - $113K (Glassdoor est.)               1
# $112K - $157K (Glassdoor est.)              1
# Name: Salary Estimate, Length: 809, dtype: int64

# %%
# Creating separate columns for following types of salary 
# 1. Per Hour
# 2. Employer Provided Salary
# 3. Employer est.
data_frame['hourly'] = data_frame['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
data_frame['employer provided'] = data_frame['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary' in x.lower() else 0)
data_frame['employer estimate'] = data_frame['Salary Estimate'].apply(lambda x: 1 if 'employer est.' in x.lower() else 0)

# %%
# to check if there are values in the new columns
data_frame.loc[data_frame['hourly']==1]
# Out:
#                                             Job Title  \
# 23                              Senior Data Scientist
# 21                                     Data Scientist
# 16                    Data Scientist/Big Data Analyst
# 26                                     Data Scientist
# 6                           Sr. Research Data Analyst
# 20                                     Data Scientist
# 12                  Analytics Developer, Data Science
# 28                     Athletics Gameday Statistician
# 3    Artificial Intelligence Documentation Specialist
# 4       Data Scientist(Data Bricks experience)-Hybrid
# 3                                   Data Scientist IV
# 10                                     Data Scientist
# 11                                     Data Scientist
# 14                                     Data Scientist
# 20                                Senior Data Analyst
# 14                Data Scientist /Data Analyst--H4551
# 28                                 Game Mathematician
# 11           Data Analyst - Senior - Decision Support
# 28  Senior Health Care Research / Senior Healthcar...
# 22                Basketball Scorekeeper/Statistician
# 25                                     Data Scientist
# 23                             Data Analyst/Scientist
# 25                                  Data Scientist II
# 4   Federal Work Study Student - Athletics Statist...
# 11                                       Statistician
# 13                           IT Data Scientist (NC48)
# 16                   Chemical Exposure Data Scientist
# 17                                     Data Scientist
# 24                   Data Scientist, Machine Learning
# 25                                     DATA SCIENTIST
# 27                   Chemical Exposure Data Scientist
# 33                   Data Scientist, Machine Learning
# 42                          Machine Learning Engineer
# 3                                      Data Scientist
# 11                                       Data Analyst
# 12                           Associate Data Scientist
# 10                                     Data Scientist
# 6                                      Data Scientist
# 3                          Digital Data Scientist (H)
# 21                            Data Scientist [Remote]
#
#                                  Salary Estimate  \
# 23   Employer Provided Salary:$70 - $75 Per Hour
# 21   Employer Provided Salary:$75 - $80 Per Hour
# 16   Employer Provided Salary:$50 - $60 Per Hour
# 26   Employer Provided Salary:$65 - $70 Per Hour
# 6    Employer Provided Salary:$28 - $38 Per Hour
# 20   Employer Provided Salary:$45 - $65 Per Hour
# 12   Employer Provided Salary:$35 - $52 Per Hour
# 28         Employer Provided Salary:$25 Per Hour
# 3    Employer Provided Salary:$20 - $23 Per Hour
# 4    Employer Provided Salary:$35 - $46 Per Hour
# 3          Employer Provided Salary:$84 Per Hour
# 10   Employer Provided Salary:$70 - $75 Per Hour
# 11         Employer Provided Salary:$85 Per Hour
# 14   Employer Provided Salary:$70 - $80 Per Hour
# 20         Employer Provided Salary:$57 Per Hour
# 14   Employer Provided Salary:$40 - $45 Per Hour
# 28   Employer Provided Salary:$20 - $59 Per Hour
# 11   Employer Provided Salary:$43 - $67 Per Hour
# 28   Employer Provided Salary:$33 - $50 Per Hour
# 22   Employer Provided Salary:$13 - $15 Per Hour
# 25   Employer Provided Salary:$65 - $70 Per Hour
# 23         Employer Provided Salary:$40 Per Hour
# 25   Employer Provided Salary:$57 - $65 Per Hour
# 4          Employer Provided Salary:$13 Per Hour
# 11   Employer Provided Salary:$33 - $39 Per Hour
# 13   Employer Provided Salary:$58 - $63 Per Hour
# 16         Employer Provided Salary:$31 Per Hour
# 17   Employer Provided Salary:$70 - $75 Per Hour
# 24         Employer Provided Salary:$50 Per Hour
# 25   Employer Provided Salary:$63 - $65 Per Hour
# 27         Employer Provided Salary:$31 Per Hour
# 33         Employer Provided Salary:$63 Per Hour
# 42   Employer Provided Salary:$70 - $80 Per Hour
# 3    Employer Provided Salary:$36 - $63 Per Hour
# 11   Employer Provided Salary:$40 - $45 Per Hour
# 12   Employer Provided Salary:$30 - $34 Per Hour
# 10   Employer Provided Salary:$39 - $40 Per Hour
# 6    Employer Provided Salary:$50 - $60 Per Hour
# 3    Employer Provided Salary:$50 - $55 Per Hour
# 21  Employer Provided Salary:$90 - $110 Per Hour
#
#                                       Job Description  Rating  \
# 23  Experienced in data science / machine learning...    -1.0
# 21  Overview:\nA data scientist requires large amo...     4.0
# 16  Data Scientist / Big Data Specialist\nLocation...     4.7
# 26  Hi,\nGreetings...!\nTitle: Data Scientist\nDur...     3.5
# 6   We are seeking a Sr. Research Data Analyst who...     4.1
# 20  Data Scientist Contractor\nKaizen Analytix LLC...    -1.0
# 12  Analytics Developer, Data Science\nThis is a f...     3.9
# 28  Job no: 494161\nWork type: Staff Part-Time\nLo...     3.9
# 3   Could Conversely AI be your next move? Your fu...    -1.0
# 4   Job Title: Data Scientist\nLocation: Detroit, ...    -1.0
# 3   Job Title: Data Scientist IV\nLocation: Menlo ...     3.8
# 10  Job title: Data Scientist\nLocation: MTV, CA (...     3.8
# 11  Job Title: Data Scientist\nLocation: Santa Cla...    -1.0
# 14  Data Scientist\nMachine Learning, Data Visuali...    -1.0
# 20  Accountabilities\nEngage with business Analyst...     4.1
# 14  Roles and Responsibilities:\nSupport client's ...     3.7
# 28  Job Title is Game Mathematician\nWhat you will...    -1.0
# 11  Job Description:\nThis position focuses the ma...     3.6
# 28  Job Details\n\nJob Class: Research Scientist 3...     3.7
# 22  Open Gym Premier, Southern California's #1 bas...    -1.0
# 25  Hi ,\nGreetings from Fiable Consulting Inc\nWe...    -1.0
# 23  Location: Philadelphia,PA\nDuration: Long Term...     4.3
# 25  Qualifications:\nEducation Minimum Requirement...     3.5
# 4   Hiring Salary Range\n\n$13.00/per hour\nNot El...     3.5
# 11  Company Name: Sciome LLC\nAddress: 2 Davis Dri...    -1.0
# 13  The client is looking for a candidate who will...    -1.0
# 16  Organization\nU.S. Environmental Protection Ag...     4.0
# 17  Job Description:\nExceptional technical writin...     4.3
# 24  JOB OVERVIEW\nAre you a Data Scientist with si...     4.1
# 25  Stefanini Group is hiring!\nExciting opportuni...     3.7
# 27  Overview:\nThe EPA National Student Services C...     4.0
# 33  Job Title: Marketing Data Scientist\nLocation:...     4.4
# 42  Role – ML Ops Engineer (ML Ops experience mand...     3.5
# 3   Announcement\nDetails\nOpen Date\n12/02/2020\n...     4.2
# 11  Location: HYBRID (2 days onsite) - San Diego, ...     4.0
# 12  San Diego, CA\nOrder: 224098\nOrder Type : Tem...     4.6
# 10  Data Scientist - Upstream R&D Cell Culture\n*T...     3.9
# 6   Data Scientist\nNewark, NJ (Hybrid, must be wi...     4.1
# 3   Digital Data Scientist (H)\nA leading biotechn...     4.8
# 21  JOB TYPE: Freelance, Contract Position (no age...     4.6
#
#                                     Company Name                    Location  \
# 23                       Enormous Enterprise LLC                  McLean, VA
# 21                      Professional Alternative                 Atlanta, GA
# 16                                   PRISMITCORP                  Austin, TX
# 26  NexWave Talent Management Solutions Pvt Ltd.                  Austin, TX
# 6                       Johns Hopkins University               Baltimore, MD
# 20                               Kaizen Analytix                  Dallas, TX
# 12                                      UCHealth                  Aurora, CO
# 28                      The University Of Denver                  Denver, CO
# 3                                  Conversely AI        Bloomfield Hills, MI
# 4                        IPS Technology Services                 Detroit, MI
# 3                            Tailored Management              Menlo Park, CA
# 10  NexWave Talent Management Solutions Pvt Ltd.           Mountain View, CA
# 11                           Zodiac Solution Inc               Sunnyvale, CA
# 14                              Saransh Realtors             Santa Clara, CA
# 20                                       Wiverse             Kansas City, MO
# 14                         CSM Software USA, LLC                Torrance, CA
# 28               VA-Com Online Employment Agency             Los Angeles, CA
# 11                      Intermountain Healthcare               Las Vegas, NV
# 28                            State of Minnesota              Saint Paul, MN
# 22                              Open Gym Premier                 Oakland, CA
# 25                         FIABLE CONSULTING INC           San Francisco, CA
# 23                         Career Soft Solutions            Philadelphia, PA
# 25                               Freyr Solutions              West Point, PA
# 4                    Maricopa Community Colleges                 Phoenix, AZ
# 11                                    Sciome LLC  Research Triangle Park, NC
# 13           Resource Management Associates LLC.                 Raleigh, NC
# 16    U.S. Environmental Protection Agency (EPA)  Research Triangle Park, NC
# 17                                  Infologitech                 Raleigh, NC
# 24                              BASF Corporation             Morrisville, NC
# 25                               Stefanini Group                  Durham, NC
# 27                                          ORAU  Research Triangle Park, NC
# 33                                    eTeam Inc.             Morrisville, NC
# 42                             Digital Dhara LLC                 Raleigh, NC
# 3                             University of Utah          Salt Lake City, UT
# 11                                Insight Global               San Diego, CA
# 12                 Eastridge Workforce Solutions               San Diego, CA
# 10                                MilliporeSigma             Saint Louis, MO
# 6                                    Brooksource                  Newark, NJ
# 3                              Avispa Technology     South San Francisco, CA
# 21                                    Braintrust           San Francisco, CA
#
#                        Size  Founded               Type of ownership  \
# 23      51 to 200 Employees     2016               Company - Private
# 21                  Unknown     1995               Company - Private
# 16        1 to 50 Employees       -1               Company - Private
# 26                  Unknown       -1               Company - Private
# 6          10000+ Employees     1876            College / University
# 20                       -1       -1                              -1
# 12         10000+ Employees     2006                        Hospital
# 28   1001 to 5000 Employees     1864            College / University
# 3                        -1       -1                              -1
# 4                   Unknown       -1                Company - Public
# 3       51 to 200 Employees     2002               Company - Private
# 10    501 to 1000 Employees     2007                        Contract
# 11                       -1       -1                              -1
# 14                       -1       -1                              -1
# 20      51 to 200 Employees     2017               Company - Private
# 14    501 to 1000 Employees       -1               Company - Private
# 28                       -1       -1                              -1
# 11         10000+ Employees     1975          Nonprofit Organization
# 28         10000+ Employees     1967                      Government
# 22                       -1       -1                              -1
# 25      51 to 200 Employees     2017               Company - Private
# 23        1 to 50 Employees     2004         Private Practice / Firm
# 25   1001 to 5000 Employees     2007               Company - Private
# 4          10000+ Employees     1990            College / University
# 11                       -1       -1                              -1
# 13        1 to 50 Employees       -1               Company - Private
# 16    501 to 1000 Employees     1946          Nonprofit Organization
# 17        1 to 50 Employees       -1               Company - Private
# 24    501 to 1000 Employees     1999               Company - Private
# 25         10000+ Employees     1987  Subsidiary or Business Segment
# 27    501 to 1000 Employees     1946          Nonprofit Organization
# 33  5001 to 10000 Employees     1999               Company - Private
# 42        1 to 50 Employees       -1               Company - Private
# 3          10000+ Employees     1850            College / University
# 11   1001 to 5000 Employees     2001               Company - Private
# 12     201 to 500 Employees     1972               Company - Private
# 10         10000+ Employees     2014  Subsidiary or Business Segment
# 6     501 to 1000 Employees     2000               Company - Private
# 3       51 to 200 Employees     2011               Company - Private
# 21                  Unknown     2018               Company - Private
#
#                                    Industry  \
# 23  Information Technology Support Services
# 21  Information Technology Support Services
# 16  Information Technology Support Services
# 26  Information Technology Support Services
# 6                   Colleges & Universities
# 20                                       -1
# 12         Health Care Services & Hospitals
# 28                  Colleges & Universities
# 3                                        -1
# 4                                        -1
# 3                             HR Consulting
# 10  Information Technology Support Services
# 11                                       -1
# 14                                       -1
# 20              Telecommunications Services
# 14                                       -1
# 28                                       -1
# 11         Health Care Services & Hospitals
# 28                State & Regional Agencies
# 22                                       -1
# 25  Information Technology Support Services
# 23  Information Technology Support Services
# 25  Information Technology Support Services
# 4                   Colleges & Universities
# 11                                       -1
# 13                                       -1
# 16     Grantmaking & Charitable Foundations
# 17  Information Technology Support Services
# 24                            HR Consulting
# 25  Information Technology Support Services
# 27     Grantmaking & Charitable Foundations
# 33                Staffing & Subcontracting
# 42                                       -1
# 3                   Colleges & Universities
# 11                            HR Consulting
# 12                            HR Consulting
# 10                Biotech & Pharmaceuticals
# 6                             HR Consulting
# 3                             HR Consulting
# 21                      Business Consulting
#
#                                 Sector                     Revenue  hourly  \
# 23              Information Technology    Unknown / Non-Applicable       1
# 21              Information Technology    Unknown / Non-Applicable       1
# 16              Information Technology  Less than $1 million (USD)       1
# 26              Information Technology    Unknown / Non-Applicable       1
# 6                            Education      $1 to $5 billion (USD)       1
# 20                                  -1                          -1       1
# 12                          Healthcare    Unknown / Non-Applicable       1
# 28                           Education  $100 to $500 million (USD)       1
# 3                                   -1                          -1       1
# 4                                   -1    Unknown / Non-Applicable       1
# 3           Human Resources & Staffing   $25 to $100 million (USD)       1
# 10              Information Technology    Unknown / Non-Applicable       1
# 11                                  -1                          -1       1
# 14                                  -1                          -1       1
# 20                  Telecommunications    Unknown / Non-Applicable       1
# 14                                  -1    Unknown / Non-Applicable       1
# 28                                  -1                          -1       1
# 11                          Healthcare     $5 to $10 billion (USD)       1
# 28  Government & Public Administration    Unknown / Non-Applicable       1
# 22                                  -1                          -1       1
# 25              Information Technology    Unknown / Non-Applicable       1
# 23              Information Technology    Unknown / Non-Applicable       1
# 25              Information Technology   $25 to $100 million (USD)       1
# 4                            Education  $100 to $500 million (USD)       1
# 11                                  -1                          -1       1
# 13                                  -1    Unknown / Non-Applicable       1
# 16                     Nonprofit & NGO   $25 to $100 million (USD)       1
# 17              Information Technology      $1 to $5 million (USD)       1
# 24          Human Resources & Staffing   $25 to $100 million (USD)       1
# 25              Information Technology      $1 to $5 billion (USD)       1
# 27                     Nonprofit & NGO   $25 to $100 million (USD)       1
# 33          Human Resources & Staffing  $100 to $500 million (USD)       1
# 42                                  -1    Unknown / Non-Applicable       1
# 3                            Education      $1 to $5 billion (USD)       1
# 11          Human Resources & Staffing   $25 to $100 million (USD)       1
# 12          Human Resources & Staffing  $100 to $500 million (USD)       1
# 10      Pharmaceutical & Biotechnology          $10+ billion (USD)       1
# 6           Human Resources & Staffing  $100 to $500 million (USD)       1
# 3           Human Resources & Staffing     $5 to $25 million (USD)       1
# 21             Management & Consulting     $5 to $25 million (USD)       1
#
#     employer provided  employer estimate
# 23                  1                  0
# 21                  1                  0
# 16                  1                  0
# 26                  1                  0
# 6                   1                  0
# 20                  1                  0
# 12                  1                  0
# 28                  1                  0
# 3                   1                  0
# 4                   1                  0
# 3                   1                  0
# 10                  1                  0
# 11                  1                  0
# 14                  1                  0
# 20                  1                  0
# 14                  1                  0
# 28                  1                  0
# 11                  1                  0
# 28                  1                  0
# 22                  1                  0
# 25                  1                  0
# 23                  1                  0
# 25                  1                  0
# 4                   1                  0
# 11                  1                  0
# 13                  1                  0
# 16                  1                  0
# 17                  1                  0
# 24                  1                  0
# 25                  1                  0
# 27                  1                  0
# 33                  1                  0
# 42                  1                  0
# 3                   1                  0
# 11                  1                  0
# 12                  1                  0
# 10                  1                  0
# 6                   1                  0
# 3                   1                  0
# 21                  1                  0

# %% [markdown]
# We observed all the rows with string 'per hour' also contain string 'employer provided salary'.

# %%
# Removing text after bracket from salary column
salary = data_frame['Salary Estimate'].apply(lambda x: x.split('(')[0])

# %%
salary.head(40)
# Out:
# 0                                   $76K - $120K
# 1                                  $101K - $138K
# 2                                   $74K - $109K
# 3                                  $116K - $161K
# 4                                   $76K - $108K
# 5           Employer Provided Salary:$65K - $205K
# 6                                   $87K - $126K
# 7          Employer Provided Salary:$100K - $125K
# 8          Employer Provided Salary:$125K - $185K
# 9                                   $96K - $137K
# 10         Employer Provided Salary:$160K - $200K
# 11         Employer Provided Salary:$110K - $115K
# 12                 Employer Provided Salary:$215K
# 13          Employer Provided Salary:$50K - $300K
# 14                                   $46K - $73K
# 15         Employer Provided Salary:$120K - $130K
# 16                                  $83K - $125K
# 17          Employer Provided Salary:$62K - $117K
# 18          Employer Provided Salary:$96K - $237K
# 19                                  $91K - $131K
# 20                                   $48K - $74K
# 21                                  $89K - $127K
# 22         Employer Provided Salary:$100K - $130K
# 23    Employer Provided Salary:$70 - $75 Per Hour
# 24         Employer Provided Salary:$100K - $140K
# 25                                  $86K - $129K
# 26                                  $88K - $138K
# 27                                  $90K - $132K
# 28         Employer Provided Salary:$170K - $198K
# 29                                  $97K - $139K
# 30                                  $95K - $137K
# 32                                  $95K - $137K
# 33                                  $95K - $137K
# 34                                  $95K - $137K
# 35                                  $95K - $137K
# 36                                  $95K - $137K
# 37                                  $95K - $137K
# 38                                  $95K - $137K
# 39                                  $95K - $137K
# 40                                  $95K - $137K
# Name: Salary Estimate, dtype: object

# %%
# Removing K and $ from the salary column
minus_Kd = salary.apply(lambda x: x.replace('K','').replace('$',''))

# %%
# to check how many rows still contains any alphabet values 
minus_Kd.str.contains('[a-zA-Z]').sum()
# Out:
# 291

# %%
# Number of rows with Employer in them
minus_Kd.str.contains('Employer').sum()
# Out:
# 291

# %% [markdown]
# All the alphabetic rows have word 'Employer' in them. If we remove all the text from the employer rows, it should work.

# %%
min_hr = minus_Kd.apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:',''))

# %%
data_frame['min_salary'] = min_hr.apply(lambda x: int(x.split('-')[0]) if '-' in x else np.NaN)
data_frame['max_salary'] = min_hr.apply(lambda x: int(x.split('-')[1]) if '-' in x else np.NaN)

# %%
data_frame['avg_salary'] =(data_frame.min_salary+data_frame.max_salary)/2

# %%
#If range not provided, assigned the sigle value salary available
data_frame['avg_salary'][data_frame['avg_salary'].isna()] = min_hr
# Out:
# C:\Users\WM796GU\AppData\Local\Temp\ipykernel_39552\456859982.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['avg_salary'][data_frame['avg_salary'].isna()] = min_hr

# %%
data_frame.head(50)
# Out:
#                                             Job Title  \
# 0             Geospatial Researcher/Data Scientist IV
# 1                               Senior Data Scientist
# 2   Software Integrator / Data Scientist - Expert ...
# 3                                 Lead Data Scientist
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                           Defense Data Scientist II
# 7                                 Senior Data Analyst
# 8                                      Data Scientist
# 9                     Defense Senior Data Scientist I
# 10                                     Data Scientist
# 11                                     Data Scientist
# 12                 2023771 Data Scientist $215,000.00
# 13                              DATA SCIENTIST - USMS
# 14                                Junior Data Labeler
# 15                                     Data Scientist
# 16                     Tech Excellence Data Scientist
# 17                                     Data Scientist
# 18                              Senior Data Scientist
# 19                                     Data Scientist
# 20               Jr. Data Scientist (Remote Eligible)
# 21                                   Data Scientist I
# 22                                     Data Scientist
# 23                              Senior Data Scientist
# 24               Data Scientist - Electricity Markets
# 25                Data Scientist - Clearance Required
# 26                      Data Scientist with Polygraph
# 27                                     Data Scientist
# 28             Senior Data Scientist (Remote/On Site)
# 29                                     Data Scientist
# 30                         Defense Data Scientist III
# 32  Pharmaceutical/Biotech Market Research Data Sc...
# 33                             Data Scientist, Junior
# 34                                     Data Scientist
# 35   Jr. Machine Learning Data Scientist - Python / R
# 36                                     Data Scientist
# 37              Tech Excellence Data Engineer, Junior
# 38                                     Data Scientist
# 39                             Data Scientist/Analyst
# 40                        Data Scientist (ALL LEVELS)
# 41                                     Data Scientist
# 42                                     Data Scientist
# 43                              Junior Data Scientist
# 44                    Data Scientist / Data Analytics
# 45                                     Data Scientist
# 46                            Aviation Data Scientist
# 47                                     Data Scientist
# 48      Data Scientist (Hybrid) (Intelligence Center)
# 49                                     Data Scientist
# 50                                     Data Scientist
#
#                                 Salary Estimate  \
# 0                 $76K - $120K (Glassdoor est.)
# 1                $101K - $138K (Glassdoor est.)
# 2                 $74K - $109K (Glassdoor est.)
# 3                $116K - $161K (Glassdoor est.)
# 4                 $76K - $108K (Glassdoor est.)
# 5         Employer Provided Salary:$65K - $205K
# 6                 $87K - $126K (Glassdoor est.)
# 7        Employer Provided Salary:$100K - $125K
# 8        Employer Provided Salary:$125K - $185K
# 9                 $96K - $137K (Glassdoor est.)
# 10       Employer Provided Salary:$160K - $200K
# 11       Employer Provided Salary:$110K - $115K
# 12               Employer Provided Salary:$215K
# 13        Employer Provided Salary:$50K - $300K
# 14                 $46K - $73K (Glassdoor est.)
# 15       Employer Provided Salary:$120K - $130K
# 16                $83K - $125K (Glassdoor est.)
# 17        Employer Provided Salary:$62K - $117K
# 18        Employer Provided Salary:$96K - $237K
# 19                $91K - $131K (Glassdoor est.)
# 20                 $48K - $74K (Glassdoor est.)
# 21                $89K - $127K (Glassdoor est.)
# 22       Employer Provided Salary:$100K - $130K
# 23  Employer Provided Salary:$70 - $75 Per Hour
# 24       Employer Provided Salary:$100K - $140K
# 25                $86K - $129K (Glassdoor est.)
# 26                $88K - $138K (Glassdoor est.)
# 27                $90K - $132K (Glassdoor est.)
# 28       Employer Provided Salary:$170K - $198K
# 29                $97K - $139K (Glassdoor est.)
# 30                $95K - $137K (Glassdoor est.)
# 32                $95K - $137K (Glassdoor est.)
# 33                $95K - $137K (Glassdoor est.)
# 34                $95K - $137K (Glassdoor est.)
# 35                $95K - $137K (Glassdoor est.)
# 36                $95K - $137K (Glassdoor est.)
# 37                $95K - $137K (Glassdoor est.)
# 38                $95K - $137K (Glassdoor est.)
# 39                $95K - $137K (Glassdoor est.)
# 40                $95K - $137K (Glassdoor est.)
# 41                $95K - $137K (Glassdoor est.)
# 42                $95K - $137K (Glassdoor est.)
# 43                $95K - $137K (Glassdoor est.)
# 44                $95K - $137K (Glassdoor est.)
# 45                $95K - $137K (Glassdoor est.)
# 46                $95K - $137K (Glassdoor est.)
# 47                $95K - $137K (Glassdoor est.)
# 48                $95K - $137K (Glassdoor est.)
# 49                $95K - $137K (Glassdoor est.)
# 50                $95K - $137K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 0   Battelle delivers when others can’t. We conduc...     3.6
# 1   JDSAT, Inc. is a solutions company - utilizing...     4.3
# 2   *** Must have TS/SCI ***\nJOB DESCRIPTION:\nIn...     4.6
# 3   Tensure is a fully-remote technology consultin...     3.8
# 4   JDSAT, Inc. is a solutions company - utilizing...     4.3
# 5   Data Scientist\nCome join the winning team on ...     4.3
# 6   Overview\n\nGuidehouse is a leading global pro...     3.7
# 7   This position requires 3 days per week onsite ...     3.8
# 8   Introduction:\nEpochGeo is looking for a Mid o...    -1.0
# 9   Overview\n\nGuidehouse is a leading global pro...     3.7
# 10  Data Scientist\nReston, Herndon, McLean, VA\nT...     5.0
# 11  Overview\nStaffing Pros, a division of VETS In...    -1.0
# 12  Position Requires a Top Secret (TS/SCI) Cleara...     5.0
# 13  The Data Scientist conducts quantitative analy...     3.6
# 14  Junior Data Labeler\n\nIn this age of disrupti...     4.0
# 15  The Program Development, Coordination, and Sup...     4.6
# 16  The Challenge:\nAre you excited at the prospec...     4.2
# 17  Duties\nAs a Data Scientist within the Geology...     4.0
# 18  Job Description:\nExperienced in data science ...    -1.0
# 19  Company Description\n\nVisa is a world leader ...     4.0
# 20  Location\nHQ\n3500 S Clark Street\nArlington, ...     3.2
# 21  YOUR LIFE'S MISSION: POSSIBLE\nYou have goals,...     4.1
# 22  The Program Development, Coordination, and Sup...    -1.0
# 23  Experienced in data science / machine learning...    -1.0
# 24  Data Scientist - Electricity Markets\nData Sci...    -1.0
# 25  Overview:\nLMI is a consultancy dedicated to p...     4.1
# 26  In this age of disruption, organizations need ...     4.0
# 27  About Us\nWe are a group of Technical Practiti...     5.0
# 28  Data Scientist\nOverview\nAs an employee, you ...    -1.0
# 29  To get the best candidate experience, please c...     4.4
# 30  Overview\n\nGuidehouse is a leading global pro...     3.7
# 32  Overview\n\nGuidehouse is a leading global pro...     3.7
# 33  Quadrint is a fast-growing, Information Techno...     4.4
# 34  At Boeing, we innovate and collaborate to make...     3.8
# 35  In this age of disruption, organizations need ...     4.0
# 36  Duties\nThis position is located in the Financ...     3.5
# 37  The Opportunity:\nEver-expanding technology li...     4.2
# 38  Overview: Staffing Pros, a division of VETS In...     3.9
# 39  Qualified candidate will become part of Perato...     3.6
# 40  Responsibilities:\nNoblis is seeking to hire D...     4.3
# 41  Pluribus Digital is looking for a talented Dat...     4.9
# 42  Harmonia Holdings Group, LLC, an award-winning...     4.1
# 43  Dark Wolf Solutions is looking for a Data Scie...     4.9
# 44  Overview:\nSkyePoint Decisions is a leading Cy...     3.5
# 45  Data Scientist\nFalls Church VA (Merrifield) /...     4.1
# 46  ATAC has an opening for an Aviation Data Scien...     3.9
# 47  Job Summary:\nLooking for a broadly talented D...     4.5
# 48  Why choose between doing meaningful work and h...     3.7
# 49  Duties\nMaking a Difference: HUD's Mission\nHU...    -1.0
# 50  Discover patterns and solve strategic business...    -1.0
#
#                                          Company Name  \
# 0                                            Battelle
# 1                                               JDSAT
# 2                                Que Technology Group
# 3                                  Tensure Consulting
# 4                                               JDSAT
# 5                                       GS Consulting
# 6                                          Guidehouse
# 7                            Bloomberg Industry Group
# 8                                            EpochGeo
# 9                                          Guidehouse
# 10                               The Josef Group Inc.
# 11             Staffing Pros, a division of VETS-inc.
# 12                                             B4CORP
# 13                                       Venesco, LLC
# 14                                           Deloitte
# 15                         Delaware Nation Industries
# 16                                Booz Allen Hamilton
# 17                               US Geological Survey
# 18                                   BRO. Consultants
# 19                                               Visa
# 20                                            Lidl US
# 21                          Navy Federal Credit Union
# 22                                                DNI
# 23                            Enormous Enterprise LLC
# 24                                  Potomac Economics
# 25                     Logistics Management Institute
# 26                                           Deloitte
# 27                                         whiteSpace
# 28                                          SourceFly
# 29                                         Salesforce
# 30                                         Guidehouse
# 32                                         Guidehouse
# 33                                     Quadrint, Inc.
# 34                                             BOEING
# 35                                           Deloitte
# 36                             US Library of Congress
# 37                                Booz Allen Hamilton
# 38           Veterans Enterprise Technology Solutions
# 39                                            Peraton
# 40                                             Noblis
# 41                                   Pluribus Digital
# 42                       Harmonia Holdings Group, LLC
# 43                                Dark Wolf Solutions
# 44                                SkyePoint Decisions
# 45                                        Marathon TS
# 46                                               ATAC
# 47                           DT Professional Services
# 48                              The MITRE Corporation
# 49  US Office of Departmental Equal Employment Opp...
# 50                                          VivusTech
#
#                    Location                     Size  Founded  \
# 0          Fort Belvoir, VA   1001 to 5000 Employees     1929
# 1                McLean, VA        1 to 50 Employees       -1
# 2                McLean, VA        1 to 50 Employees       -1
# 3            Washington, DC        1 to 50 Employees       -1
# 4                McLean, VA        1 to 50 Employees       -1
# 5   Fort George G Meade, MD        1 to 50 Employees       -1
# 6                McLean, VA   1001 to 5000 Employees     2018
# 7            Washington, DC   1001 to 5000 Employees     1929
# 8            Washington, DC                       -1       -1
# 9                McLean, VA   1001 to 5000 Employees     2018
# 10              Herndon, VA        1 to 50 Employees       -1
# 11            Arlington, VA                       -1       -1
# 12               McLean, VA      51 to 200 Employees       -1
# 13            Arlington, VA     201 to 500 Employees     2004
# 14              Rosslyn, VA         10000+ Employees     1850
# 15            Arlington, VA                  Unknown       -1
# 16           Alexandria, VA         10000+ Employees     1914
# 17               Reston, VA  5001 to 10000 Employees     1879
# 18               McLean, VA                  Unknown       -1
# 19            Arlington, VA         10000+ Employees     1958
# 20            Arlington, VA  5001 to 10000 Employees     1973
# 21               Vienna, VA         10000+ Employees     1933
# 22            Arlington, VA                       -1       -1
# 23               McLean, VA      51 to 200 Employees     2016
# 24              Fairfax, VA                       -1       -1
# 25        Tysons Corner, VA   1001 to 5000 Employees     1961
# 26              Rosslyn, VA         10000+ Employees     1850
# 27           Washington, DC        1 to 50 Employees       -1
# 28         Fort Belvoir, VA                       -1       -1
# 29           Washington, DC         10000+ Employees     1999
# 30               McLean, VA   1001 to 5000 Employees     2018
# 32        Tysons Corner, VA   1001 to 5000 Employees     2018
# 33               McLean, VA      51 to 200 Employees     2000
# 34           Fort Meade, MD         10000+ Employees     1916
# 35              Rosslyn, VA         10000+ Employees     1850
# 36           Washington, DC   1001 to 5000 Employees     1800
# 37            Chantilly, VA         10000+ Employees     1914
# 38            Arlington, VA      51 to 200 Employees     2005
# 39            Arlington, VA         10000+ Employees     2017
# 40               Reston, VA   1001 to 5000 Employees     1996
# 41            Arlington, VA      51 to 200 Employees     1995
# 42               McLean, VA     201 to 500 Employees     2006
# 43               McLean, VA      51 to 200 Employees     2019
# 44              Rosslyn, VA        1 to 50 Employees     2009
# 45          Springfield, VA     201 to 500 Employees     2009
# 46            Arlington, VA      51 to 200 Employees       -1
# 47           Merrifield, VA        1 to 50 Employees     2013
# 48               McLean, VA  5001 to 10000 Employees     1958
# 49           Washington, DC                       -1       -1
# 50            Chantilly, VA                  Unknown       -1
#
#          Type of ownership                                 Industry  \
# 0   Nonprofit Organization                   Research & Development
# 1        Company - Private                                       -1
# 2        Company - Private                                       -1
# 3        Company - Private                                       -1
# 4        Company - Private                                       -1
# 5        Company - Private                                       -1
# 6        Company - Private                      Business Consulting
# 7        Company - Private                               Publishing
# 8                       -1                                       -1
# 9        Company - Private                      Business Consulting
# 10       Company - Private                                       -1
# 11                      -1                                       -1
# 12       Company - Private  Information Technology Support Services
# 13        Company - Public  Information Technology Support Services
# 14       Company - Private                         Accounting & Tax
# 15                Contract                        National Agencies
# 16        Company - Public                      Business Consulting
# 17              Government                        National Agencies
# 18        Company - Public                                       -1
# 19        Company - Public  Information Technology Support Services
# 20       Company - Private                           Grocery Stores
# 21           Self-employed                        Banking & Lending
# 22                      -1                                       -1
# 23       Company - Private  Information Technology Support Services
# 24                      -1                                       -1
# 25       Company - Private                      Business Consulting
# 26       Company - Private                         Accounting & Tax
# 27           Self-employed                                       -1
# 28                      -1                                       -1
# 29        Company - Public  Enterprise Software & Network Solutions
# 30       Company - Private                      Business Consulting
# 32       Company - Private                      Business Consulting
# 33       Company - Private  Information Technology Support Services
# 34        Company - Public                      Aerospace & Defense
# 35       Company - Private                         Accounting & Tax
# 36              Government                  Culture & Entertainment
# 37        Company - Public                      Business Consulting
# 38       Company - Private                        National Agencies
# 39       Company - Private  Information Technology Support Services
# 40  Nonprofit Organization                      Business Consulting
# 41       Company - Private  Information Technology Support Services
# 42       Company - Private            Computer Hardware Development
# 43       Company - Private                                       -1
# 44       Company - Private  Information Technology Support Services
# 45       Company - Private                            HR Consulting
# 46       Company - Private            Education & Training Services
# 47        Company - Public                                       -1
# 48  Nonprofit Organization                        National Agencies
# 49                      -1                                       -1
# 50        Company - Public                                       -1
#
#                                 Sector                           Revenue  \
# 0              Management & Consulting           $5 to $10 billion (USD)
# 1                                   -1          Unknown / Non-Applicable
# 2                                   -1        Less than $1 million (USD)
# 3                                   -1          Unknown / Non-Applicable
# 4                                   -1          Unknown / Non-Applicable
# 5                                   -1          Unknown / Non-Applicable
# 6              Management & Consulting          Unknown / Non-Applicable
# 7                Media & Communication        $100 to $500 million (USD)
# 8                                   -1                                -1
# 9              Management & Consulting          Unknown / Non-Applicable
# 10                                  -1          Unknown / Non-Applicable
# 11                                  -1                                -1
# 12              Information Technology          Unknown / Non-Applicable
# 13              Information Technology          Unknown / Non-Applicable
# 14                  Financial Services                $10+ billion (USD)
# 15  Government & Public Administration          Unknown / Non-Applicable
# 16             Management & Consulting           $5 to $10 billion (USD)
# 17  Government & Public Administration          Unknown / Non-Applicable
# 18                                  -1          Unknown / Non-Applicable
# 19              Information Technology                $10+ billion (USD)
# 20                  Retail & Wholesale          Unknown / Non-Applicable
# 21                  Financial Services          Unknown / Non-Applicable
# 22                                  -1                                -1
# 23              Information Technology          Unknown / Non-Applicable
# 24                                  -1                                -1
# 25             Management & Consulting        $100 to $500 million (USD)
# 26                  Financial Services                $10+ billion (USD)
# 27                                  -1          Unknown / Non-Applicable
# 28                                  -1                                -1
# 29              Information Technology                $10+ billion (USD)
# 30             Management & Consulting          Unknown / Non-Applicable
# 32             Management & Consulting          Unknown / Non-Applicable
# 33              Information Technology          Unknown / Non-Applicable
# 34                 Aerospace & Defense                $10+ billion (USD)
# 35                  Financial Services                $10+ billion (USD)
# 36    Arts, Entertainment & Recreation  $500 million to $1 billion (USD)
# 37             Management & Consulting           $5 to $10 billion (USD)
# 38  Government & Public Administration         $25 to $100 million (USD)
# 39              Information Technology           $5 to $10 billion (USD)
# 40             Management & Consulting        $100 to $500 million (USD)
# 41              Information Technology          Unknown / Non-Applicable
# 42              Information Technology         $25 to $100 million (USD)
# 43                                  -1          Unknown / Non-Applicable
# 44              Information Technology           $5 to $25 million (USD)
# 45          Human Resources & Staffing         $25 to $100 million (USD)
# 46                           Education           $5 to $25 million (USD)
# 47                                  -1        Less than $1 million (USD)
# 48  Government & Public Administration            $1 to $5 billion (USD)
# 49                                  -1                                -1
# 50                                  -1          Unknown / Non-Applicable
#
#     hourly  employer provided  employer estimate  min_salary  max_salary  \
# 0        0                  0                  0        76.0       120.0
# 1        0                  0                  0       101.0       138.0
# 2        0                  0                  0        74.0       109.0
# 3        0                  0                  0       116.0       161.0
# 4        0                  0                  0        76.0       108.0
# 5        0                  1                  0        65.0       205.0
# 6        0                  0                  0        87.0       126.0
# 7        0                  1                  0       100.0       125.0
# 8        0                  1                  0       125.0       185.0
# 9        0                  0                  0        96.0       137.0
# 10       0                  1                  0       160.0       200.0
# 11       0                  1                  0       110.0       115.0
# 12       0                  1                  0         NaN         NaN
# 13       0                  1                  0        50.0       300.0
# 14       0                  0                  0        46.0        73.0
# 15       0                  1                  0       120.0       130.0
# 16       0                  0                  0        83.0       125.0
# 17       0                  1                  0        62.0       117.0
# 18       0                  1                  0        96.0       237.0
# 19       0                  0                  0        91.0       131.0
# 20       0                  0                  0        48.0        74.0
# 21       0                  0                  0        89.0       127.0
# 22       0                  1                  0       100.0       130.0
# 23       1                  1                  0        70.0        75.0
# 24       0                  1                  0       100.0       140.0
# 25       0                  0                  0        86.0       129.0
# 26       0                  0                  0        88.0       138.0
# 27       0                  0                  0        90.0       132.0
# 28       0                  1                  0       170.0       198.0
# 29       0                  0                  0        97.0       139.0
# 30       0                  0                  0        95.0       137.0
# 32       0                  0                  0        95.0       137.0
# 33       0                  0                  0        95.0       137.0
# 34       0                  0                  0        95.0       137.0
# 35       0                  0                  0        95.0       137.0
# 36       0                  0                  0        95.0       137.0
# 37       0                  0                  0        95.0       137.0
# 38       0                  0                  0        95.0       137.0
# 39       0                  0                  0        95.0       137.0
# 40       0                  0                  0        95.0       137.0
# 41       0                  0                  0        95.0       137.0
# 42       0                  0                  0        95.0       137.0
# 43       0                  0                  0        95.0       137.0
# 44       0                  0                  0        95.0       137.0
# 45       0                  0                  0        95.0       137.0
# 46       0                  0                  0        95.0       137.0
# 47       0                  0                  0        95.0       137.0
# 48       0                  0                  0        95.0       137.0
# 49       0                  0                  0        95.0       137.0
# 50       0                  0                  0        95.0       137.0
#
#    avg_salary
# 0        98.0
# 1       119.5
# 2        91.5
# 3       138.5
# 4        92.0
# 5       135.0
# 6       106.5
# 7       112.5
# 8       155.0
# 9       116.5
# 10      180.0
# 11      112.5
# 12        215
# 13      175.0
# 14       59.5
# 15      125.0
# 16      104.0
# 17       89.5
# 18      166.5
# 19      111.0
# 20       61.0
# 21      108.0
# 22      115.0
# 23       72.5
# 24      120.0
# 25      107.5
# 26      113.0
# 27      111.0
# 28      184.0
# 29      118.0
# 30      116.0
# 32      116.0
# 33      116.0
# 34      116.0
# 35      116.0
# 36      116.0
# 37      116.0
# 38      116.0
# 39      116.0
# 40      116.0
# 41      116.0
# 42      116.0
# 43      116.0
# 44      116.0
# 45      116.0
# 46      116.0
# 47      116.0
# 48      116.0
# 49      116.0
# 50      116.0

# %%
#state of the job location
df['job_state'] = df['Location'].apply(lambda x: x.split(',')[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 #state of the job location
# ----> 2 df['job_state'] = df['Location'].apply(lambda x: x.split(',')[1])
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [21], in <lambda>(x)
#       1 #state of the job location
# ----> 2 df['job_state'] = df['Location'].apply(lambda x: x.split(',')[1])
#
# IndexError: list index out of range

# %%
# Figuring out reason for the error.
data_frame['Location'][~data_frame['Location'].str.contains(',')].value_counts()
# Out:
# United States    17
# Manhattan        17
# California       15
# Texas             3
# St Louis Park     2
# Florida           2
# Hawaii            1
# Pennsylvania      1
# Name: Location, dtype: int64

# %% [markdown]
# Rows which have above locations do not contain character ',' in them. This is leading to the above error in accessing the second item of the list.

# %%
states = data_frame['Location'][~data_frame['Location'].str.contains(',')].value_counts().index

# %%
data_frame['job_state'] = data_frame['Location'].apply(lambda x: x if x in states else x.split(',')[1])

# %%
data_frame['job_state'].value_counts()
# Out:
#  CA              610
#  TX              278
#  OH              253
#  FL              253
#  NC              182
#  NY              163
#  MO              106
#  MD              106
#  VA              102
#  MA               97
#  AZ               90
#  MI               86
#  CO               83
#  IL               82
#  WA               82
#  UT               80
#  OR               80
#  GA               76
#  MN               76
#  PA               63
#  IN               59
#  TN               54
#  DC               47
#  QC               36
#  NV               34
#  KS               24
#  NJ               18
#  HI               17
# United States     17
# Manhattan         17
# California        15
#  DE                6
#  Cuyahoga          3
# Texas              3
# St Louis Park      2
# Florida            2
# Hawaii             1
# Pennsylvania       1
#  KY                1
#  SC                1
# Name: job_state, dtype: int64

# %%
# Removing leading zeros
data_frame['job_state'] = data_frame['job_state'].apply(lambda x: x.lstrip(' '))

# %%
# Removing Quebec, Canada jobs
data_frame = data_frame[data_frame['job_state']!='QC']

# %%
data_frame['job_state'].value_counts()
# Out:
# CA               610
# TX               278
# FL               253
# OH               253
# NC               182
# NY               163
# MD               106
# MO               106
# VA               102
# MA                97
# AZ                90
# MI                86
# CO                83
# WA                82
# IL                82
# OR                80
# UT                80
# GA                76
# MN                76
# PA                63
# IN                59
# TN                54
# DC                47
# NV                34
# KS                24
# NJ                18
# HI                17
# United States     17
# Manhattan         17
# California        15
# DE                 6
# Cuyahoga           3
# Texas              3
# St Louis Park      2
# Florida            2
# Hawaii             1
# Pennsylvania       1
# KY                 1
# SC                 1
# Name: job_state, dtype: int64

# %%
data_frame['avg_salary'].describe()
# Out:
# count     3270.0
# unique     270.0
# top        155.0
# freq       161.0
# Name: avg_salary, dtype: float64

# %%
# Mapping states with 2 letter abbreviation 
data_frame['job_state'][data_frame['job_state']=='Manhattan']='NY'
data_frame['job_state'][data_frame['job_state']=='California']='CA'
data_frame['job_state'][data_frame['job_state']=='Texas']='TX'
data_frame['job_state'][data_frame['job_state']=='St Louis Park']='MN'
data_frame['job_state'][data_frame['job_state']=='Florida']='FL'
data_frame['job_state'][data_frame['job_state']=='Hawaii']='HI'
data_frame['job_state'][data_frame['job_state']=='Pennsylvania']='PA'
data_frame['job_state'][data_frame['job_state']=='Cuyahoga']='OH'
# Out:
# C:\Users\WM796GU\AppData\Local\Temp\ipykernel_39552\3010522983.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['job_state'][data_frame['job_state']=='California']='CA'
# C:\Users\WM796GU\AppData\Local\Temp\ipykernel_39552\3010522983.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['job_state'][data_frame['job_state']=='Texas']='TX'
# C:\Users\WM796GU\AppData\Local\Temp\ipykernel_39552\3010522983.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['job_state'][data_frame['job_state']=='St Louis Park']='MN'
# C:\Users\WM796GU\AppData\Local\Temp\ipykernel_39552\3010522983.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['job_state'][data_frame['job_state']=='Florida']='FL'
# C:\Users\WM796GU\AppData\Local\Temp\ipykernel_39552\3010522983.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['job_state'][data_frame['job_state']=='Hawaii']='HI'
# C:\Users\WM796GU\AppData\Local\Temp\ipykernel_39552\3010522983.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['job_state'][data_frame['job_state']=='Pennsylvania']='PA'
# C:\Users\WM796GU\AppData\Local\Temp\ipykernel_39552\3010522983.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['job_state'][data_frame['job_state']=='Cuyahoga']='OH'

# %%
data_frame['job_state'].value_counts()
# Out:
# CA               625
# TX               281
# OH               256
# FL               255
# NC               182
# NY               180
# MD               106
# MO               106
# VA               102
# MA                97
# AZ                90
# MI                86
# CO                83
# IL                82
# WA                82
# UT                80
# OR                80
# MN                78
# GA                76
# PA                64
# IN                59
# TN                54
# DC                47
# NV                34
# KS                24
# NJ                18
# HI                18
# United States     17
# DE                 6
# KY                 1
# SC                 1
# Name: job_state, dtype: int64

# %%
data_frame.head()
# Out:
#                                            Job Title  \
# 0            Geospatial Researcher/Data Scientist IV
# 1                              Senior Data Scientist
# 2  Software Integrator / Data Scientist - Expert ...
# 3                                Lead Data Scientist
# 4                                     Data Scientist
#
#                   Salary Estimate  \
# 0   $76K - $120K (Glassdoor est.)
# 1  $101K - $138K (Glassdoor est.)
# 2   $74K - $109K (Glassdoor est.)
# 3  $116K - $161K (Glassdoor est.)
# 4   $76K - $108K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Battelle delivers when others can’t. We conduc...     3.6
# 1  JDSAT, Inc. is a solutions company - utilizing...     4.3
# 2  *** Must have TS/SCI ***\nJOB DESCRIPTION:\nIn...     4.6
# 3  Tensure is a fully-remote technology consultin...     3.8
# 4  JDSAT, Inc. is a solutions company - utilizing...     4.3
#
#            Company Name          Location                    Size  Founded  \
# 0              Battelle  Fort Belvoir, VA  1001 to 5000 Employees     1929
# 1                 JDSAT        McLean, VA       1 to 50 Employees       -1
# 2  Que Technology Group        McLean, VA       1 to 50 Employees       -1
# 3    Tensure Consulting    Washington, DC       1 to 50 Employees       -1
# 4                 JDSAT        McLean, VA       1 to 50 Employees       -1
#
#         Type of ownership                Industry                   Sector  \
# 0  Nonprofit Organization  Research & Development  Management & Consulting
# 1       Company - Private                      -1                       -1
# 2       Company - Private                      -1                       -1
# 3       Company - Private                      -1                       -1
# 4       Company - Private                      -1                       -1
#
#                       Revenue  hourly  employer provided  employer estimate  \
# 0     $5 to $10 billion (USD)       0                  0                  0
# 1    Unknown / Non-Applicable       0                  0                  0
# 2  Less than $1 million (USD)       0                  0                  0
# 3    Unknown / Non-Applicable       0                  0                  0
# 4    Unknown / Non-Applicable       0                  0                  0
#
#    min_salary  max_salary avg_salary job_state
# 0        76.0       120.0       98.0        VA
# 1       101.0       138.0      119.5        VA
# 2        74.0       109.0       91.5        VA
# 3       116.0       161.0      138.5        DC
# 4        76.0       108.0       92.0        VA

# %%
data_frame['job_state'].isnull().sum()
# Out:
# 0

# %%
#age of company 
data_frame['age'] = data_frame.Founded.apply(lambda x: x if x <1 else 2022 - x)

# %%
data_frame.head()
# Out:
#                                            Job Title  \
# 0            Geospatial Researcher/Data Scientist IV
# 1                              Senior Data Scientist
# 2  Software Integrator / Data Scientist - Expert ...
# 3                                Lead Data Scientist
# 4                                     Data Scientist
#
#                   Salary Estimate  \
# 0   $76K - $120K (Glassdoor est.)
# 1  $101K - $138K (Glassdoor est.)
# 2   $74K - $109K (Glassdoor est.)
# 3  $116K - $161K (Glassdoor est.)
# 4   $76K - $108K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Battelle delivers when others can’t. We conduc...     3.6
# 1  JDSAT, Inc. is a solutions company - utilizing...     4.3
# 2  *** Must have TS/SCI ***\nJOB DESCRIPTION:\nIn...     4.6
# 3  Tensure is a fully-remote technology consultin...     3.8
# 4  JDSAT, Inc. is a solutions company - utilizing...     4.3
#
#            Company Name          Location                    Size  Founded  \
# 0              Battelle  Fort Belvoir, VA  1001 to 5000 Employees     1929
# 1                 JDSAT        McLean, VA       1 to 50 Employees       -1
# 2  Que Technology Group        McLean, VA       1 to 50 Employees       -1
# 3    Tensure Consulting    Washington, DC       1 to 50 Employees       -1
# 4                 JDSAT        McLean, VA       1 to 50 Employees       -1
#
#         Type of ownership                Industry                   Sector  \
# 0  Nonprofit Organization  Research & Development  Management & Consulting
# 1       Company - Private                      -1                       -1
# 2       Company - Private                      -1                       -1
# 3       Company - Private                      -1                       -1
# 4       Company - Private                      -1                       -1
#
#                       Revenue  hourly  employer provided  employer estimate  \
# 0     $5 to $10 billion (USD)       0                  0                  0
# 1    Unknown / Non-Applicable       0                  0                  0
# 2  Less than $1 million (USD)       0                  0                  0
# 3    Unknown / Non-Applicable       0                  0                  0
# 4    Unknown / Non-Applicable       0                  0                  0
#
#    min_salary  max_salary avg_salary job_state  age
# 0        76.0       120.0       98.0        VA   93
# 1       101.0       138.0      119.5        VA   -1
# 2        74.0       109.0       91.5        VA   -1
# 3       116.0       161.0      138.5        DC   -1
# 4        76.0       108.0       92.0        VA   -1

# %%
##parsing of job description (python, etc.)
#python
data_frame['python_yn'] = data_frame['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
data_frame.python_yn.value_counts()
# Out:
# 0    2981
# 1     289
# Name: python_yn, dtype: int64

# %%
#SQL
data_frame['sql_yn'] = data_frame['Job Description'].apply(lambda x: 1 if 'sql' in x.lower() else 0)
data_frame.sql_yn.value_counts()
# Out:
# 0    3078
# 1     192
# Name: sql_yn, dtype: int64

# %%
data_frame.to_csv('salary_data_cleaned.csv', index = False)
